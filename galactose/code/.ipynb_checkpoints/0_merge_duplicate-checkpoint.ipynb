# %%
suppressPackageStartupMessages({
    library(Signac)
    library(Seurat)
    library(GenomicRanges)
    library(data.table)
    library(Matrix)
    library(dplyr)
    library(SummarizedExperiment)
    library(ggplot2)
    library(rstatix)
    source("1_HelperFunction.R")
    source("../../global/variant_calling.R")
    set.seed(123)
    '%ni%' <- Negate('%in%')
    annotations <- readRDS("EnsDb.Hsapiens.v86_annotations_Nov2025.rds")
})

# %%
cols <- c(
  "CTRL_Glu"    = "#BBD6FF",
  "CTRL_Gal_1D" = "#2780FF",
  "CTRL_Gal_3D" = "#0040A8",
  "KI36_Glu"    = "#F0BBFF",
  "KI36_Gal_1D" = "#960096",
  "KI36_Gal_3D" = "#5A0050",
  "Doublet"     = "black", 
  "Negative"    = "grey"
)

# %%
rep1 <- read.table(
  file = "../data/rep1/cellranger/peaks.bed",
  col.names = c("chr", "start", "end")
)
rep2 <- read.table(
  file = "../data/rep2/cellranger/peaks.bed",
  col.names = c("chr", "start", "end")
)

# convert to genomic ranges
gr.rep1 <- makeGRangesFromDataFrame(rep1)
gr.rep2 <- makeGRangesFromDataFrame(rep1)

# %%
# Create a unified set of peaks to quantify in each dataset
combined.peaks <- reduce(x = c(gr.rep1, gr.rep2))

# Filter out bad peaks based on length
peakwidths <- width(combined.peaks)
combined.peaks <- combined.peaks[peakwidths  < 10000 & peakwidths > 20]
combined.peaks
# Out:
# GRanges object with 242857 ranges and 0 metadata columns:
#              seqnames          ranges strand
#                 <Rle>       <IRanges>  <Rle>
#        [1]       chr1      9897-10800      *
#        [2]       chr1     15793-16656      *
#        [3]       chr1     17158-17946      *
#        [4]       chr1   180960-181794      *
#        [5]       chr1   183938-184705      *
#        ...        ...             ...    ...
#   [242853] KI270728.1 1792061-1792779      *
#   [242854] KI270731.1       4514-5416      *
#   [242855] KI270734.1   121023-121925      *
#   [242856] KI270734.1   131912-132799      *
#   [242857] KI270734.1   133504-134383      *
#   -------
#   seqinfo: 36 sequences from an unspecified genome; no seqlengths

# %%
## Create Fragment objects
# load metadata
md.rep1 <- read.table(
  file = "../data/rep1/cellranger/singlecell.csv",
  stringsAsFactors = FALSE, sep = ",", header = TRUE, row.names = 1)[-1, ] 

md.rep2 <- read.table(
  file = "../data/rep2/cellranger/singlecell.csv", 
  stringsAsFactors = FALSE, sep = ",", header = TRUE, row.names = 1)[-1, ] 

# perform an initial filtering of low count cells
md.rep1 <- md.rep1[md.rep1$passed_filters > 500, ]
md.rep2 <- md.rep2[md.rep2$passed_filters > 500, ]

# create fragment objects
frags.rep1 <- CreateFragmentObject(
  path = "../data/rep1/cellranger/fragments.tsv.gz", cells = rownames(md.rep1)
)

frags.rep2 <- CreateFragmentObject(
  path = "../data/rep2/cellranger/fragments.tsv.gz", cells = rownames(md.rep2)
)
# Out:
# Computing hash
#
# Computing hash

# %%
## Quantify peaks in each dataset
counts.rep1 <- FeatureMatrix(
  fragments = frags.rep1,
  features = combined.peaks,
  cells = rownames(md.rep1)
)

counts.rep2 <- FeatureMatrix(
  fragments = frags.rep2,
  features = combined.peaks,
  cells = rownames(md.rep2)
)
# Out:
# Extracting reads overlapping genomic regions
#
# Extracting reads overlapping genomic regions

# %%
### Create the objects
assay.rep1 <- CreateChromatinAssay(counts.rep1, fragments = frags.rep1, annotation = annotations)
Gal.rep1 <- CreateSeuratObject(assay.rep1, assay = "ATAC", meta.data=md.rep1)

assay.rep2 <- CreateChromatinAssay(counts.rep2, fragments = frags.rep2, annotation = annotations)
Gal.rep2 <- CreateSeuratObject(assay.rep2, assay = "ATAC", meta.data=md.rep2)
# Out:
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from atac to atac_”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from atac to atac_”

# %%
## Merge objects
# add information to identify dataset of origin
Gal.rep1$duplicate <- 'rep1'; Gal.rep2$duplicate <- 'rep2'

# merge all datasets, adding a cell ID to make sure cell names are unique
Gal <- merge(
  x = Gal.rep1, y = Gal.rep2,
  add.cell.ids = c("rep1", "rep2")
)

# %%
Gal <- Gal[,Gal$is__cell_barcode == 1]

# %%
HTO <- cbind(import_hto("rep1"), import_hto("rep2"))

# %%
Gal[["HTO"]] <- CreateAssayObject(HTO[,Cells(Gal)])

# %%
# Normalize HTO data, here we use centered log-ratio (CLR) transformation
Gal <- NormalizeData(Gal, assay = "HTO", normalization.method = "CLR")
Gal <- HTODemux(Gal, assay = "HTO", positive.quantile = 0.9)
# Out:
# Normalizing across features
#
# Cutoff for HTO1 : 40 reads
#
# Cutoff for HTO2 : 61 reads
#
# Cutoff for HTO3 : 39 reads
#
# Cutoff for HTO4 : 116 reads
#
# Cutoff for HTO5 : 34 reads
#
# Cutoff for HTO6 : 119 reads

# %%
# Global classification results
table(Gal$hash.ID)
# Out:
#  Doublet     HTO2     HTO5     HTO4     HTO6     HTO1 Negative     HTO3
#     7236     2619     1975     3269     2812     2310     1691     1651

# %%
treatment <- c("Glu", "Gal_1D", "Gal_3D")
Gal$hash.ID <- factor(Gal$hash.ID, levels = c(paste0("HTO", 1:6), "Negative","Doublet"), 
                      labels = c(paste0("CTRL_", treatment), paste0("KI36_", treatment), "Negative","Doublet"))

# %%
options(repr.plot.width = 10, repr.plot.height = 6, repr.plot.res = 300)
Idents(Gal) <- "hash.ID"
(p1 <- RidgePlot(Gal, assay = "HTO", features = rownames(Gal[["HTO"]])[1:6], ncol = 3, cols = cols))
ggsave(plot = p1, "../plot/1_1_HTO_demultiplex_RidgePlot.pdf", width = 12, height = 8)
# Out:
# Picking joint bandwidth of 0.0588
#
# Picking joint bandwidth of 0.0574
#
# Picking joint bandwidth of 0.0653
#
# Picking joint bandwidth of 0.0567
#
# Picking joint bandwidth of 0.0548
#
# Picking joint bandwidth of 0.0543
#
# Picking joint bandwidth of 0.0588
#
# Picking joint bandwidth of 0.0574
#
# Picking joint bandwidth of 0.0653
#
# Picking joint bandwidth of 0.0567
#
# Picking joint bandwidth of 0.0548
#
# Picking joint bandwidth of 0.0543
# plot without title

# %%
options(repr.plot.width = 5, repr.plot.height = 3, repr.plot.res = 300)
(p2 <- HTOHeatmap(Gal, assay = "HTO") + scale_fill_viridis_c())
ggsave(plot = p2, "../plot/1_2_HTO_demultiplex_Heatmap.pdf", width = 6, height = 3)
# Out:
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
# plot without title

# %%
Gal <- subset(Gal, hash.ID != "Doublet" & hash.ID != "Negative")
Gal$cellline <- ifelse(grepl("CTRL", Gal$hash.ID), "CTRL", "KI36")

# %%
table(Gal$cellline)
# Out:
# CTRL KI36
# 6580 8056

# %%
## Quality Control
# nucleus genome ATAC QC
Gal$pct_reads_in_peaks <- Gal$peak_region_fragments / Gal$passed_filters * 100
# Gal <- TSSEnrichment(Gal, fast = T)
Gal <- NucleosomeSignal(Gal)
Gal$log10_nCount_ATAC <- log10(Gal$nCount_ATAC)

# %%
mitoSE.rep1 <- readRDS("../data/rep1/mgatk/mgatk.rds")
colnames(mitoSE.rep1) <-  paste0("rep1_", colnames(mitoSE.rep1))
mitoSE.rep2 <- readRDS("../data/rep2/mgatk/mgatk.rds")
colnames(mitoSE.rep2) <-  paste0("rep2_", colnames(mitoSE.rep2))

# %%
# combined the two mito summarized experiment object
mitoSE <- cbind(mitoSE.rep1, mitoSE.rep2)[,Cells(Gal)]

# %%
Gal$mtDNA_depth = mitoSE$depth
Gal$log10_mtDNA_depth <- log10(Gal$mtDNA_depth)

# %%
options(repr.plot.width = 10, repr.plot.height = 5, repr.plot.res = 300)
p3 <- VlnPlot(object = Gal,
        feature = c("nucleosome_signal",
                    "pct_reads_in_peaks",
                    "nCount_ATAC",
                    "log10_mtDNA_depth"), pt.size = 0, ncol = 4, cols = cols)

# %%
p3
# Out:
# plot without title

# %%
ggsave(plot = p3, "../plot/1_3_QC.pdf", width = 12, height = 4)

# %%
Gal <- subset(
  x = Gal,
  subset = nCount_ATAC > 1000 & 
    nCount_ATAC < 50000 &
    pct_reads_in_peaks > 20 &
    nucleosome_signal <= 2 &
    mtDNA_depth >= 10)
Gal
# Out:
# An object of class Seurat
# 242863 features across 13329 samples within 2 assays
# Active assay: ATAC (242857 features, 0 variable features)
#  1 other assay present: HTO

# %%
options(repr.plot.width = 12, repr.plot.height = 4, repr.plot.res = 300)
(p4 <- VlnPlot(object = Gal,
        feature = c("nucleosome_signal",
                    "pct_reads_in_peaks",
                    "nCount_ATAC",
                    "log10_mtDNA_depth"), pt.size = 0, ncol = 4, cols = cols))
# Out:
# plot without title

# %%
ggsave(plot = p4, "../plot/1_4_QC_filtered.pdf", width = 12, height = 4)

# %%
## Latent semantic indexing (LSI): Normalization (TF-IDF) followed by linear dimensional reduction (SVD)
set.seed(123)
DefaultAssay(Gal) <- "ATAC"
Gal <- RunTFIDF(Gal) # term frequency-inverse document frequency
Gal <- FindTopFeatures(Gal, min.cutoff = 'q0')
Gal <- RunSVD(Gal) # singular value decomposition
# Out:
# Performing TF-IDF normalization
#
# Running SVD
#
# Scaling cell embeddings

# %%
## Non-linear dimension reduction and clustering
set.seed(123)
Gal <- RunUMAP(object = Gal, reduction = 'lsi', dims = 2:30, reduction.name = "atac.umap", reduction.key = "atacUMAP_", verbose = F)
# Out:
# Warning message:
# “The default method for RunUMAP has changed from calling Python UMAP via reticulate to the R-native UWOT using the cosine metric
# To use Python UMAP via reticulate, set umap.method to 'umap-learn' and metric to 'correlation'
# This message will be shown once per session”

# %%
options(repr.plot.width = 9, repr.plot.height = 6, repr.plot.res = 300)
(p5 <- DimPlot(object = Gal, group.by = "hash.ID", split.by = "hash.ID", cols = cols, ncol = 3) + NoLegend())
# Out:
# plot without title

# %%
ggsave(plot = p5, "../plot/1_5_UMAP_LinexTreatment.pdf", width = 4.5, height = 3)

# %%
options(repr.plot.width = 6, repr.plot.height = 4, repr.plot.res = 300)
DimPlot(object = Gal, group.by = "duplicate", split.by = "duplicate") + NoLegend()
# Out:
# plot without title

# %%
options(repr.plot.width = 4, repr.plot.height = 4, repr.plot.res = 300)
(p6 <- DimPlot(object = Gal, group.by = "cellline", cols = c("CTRL" = "#2780FF", "KI36" = "#960096")) + NoLegend())
# Out:
# plot without title

# %%
ggsave(plot = p6, "../plot/1_6_UMAP_Line.pdf", width = 4, height = 4)

# %%
options(repr.plot.width = 10, repr.plot.height = 6, repr.plot.res = 300)
(p7 <- FeaturePlot(
    object = Gal, features = paste0("HTO", 1:6), 
    min.cutoff = "q5", max.cutoff = "q95", 
    ncol = 3, order = T) & scale_color_viridis_c())
# Out:
# Warning message:
# “Could not find HTO1 in the default search locations, found in HTO assay instead”
# Warning message:
# “Could not find HTO2 in the default search locations, found in HTO assay instead”
# Warning message:
# “Could not find HTO3 in the default search locations, found in HTO assay instead”
# Warning message:
# “Could not find HTO4 in the default search locations, found in HTO assay instead”
# Warning message:
# “Could not find HTO5 in the default search locations, found in HTO assay instead”
# Warning message:
# “Could not find HTO6 in the default search locations, found in HTO assay instead”
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
# plot without title

# %%
ggsave(plot = p7, "../plot/1_7_UMAP_HTO.pdf", width = 10, height = 6)

# %%
options(repr.plot.width = 18, repr.plot.height = 3, repr.plot.res = 300)

FeaturePlot(object = Gal, features = "mtDNA_depth", 
                  min.cutoff = "q5", max.cutoff = "q95", 
                  split.by = "hash.ID", ncol =3) & 
  scale_color_viridis_c()
# Out:
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
# plot without title

# %%
Gal$mtDNA_depth_norm <- Gal$mtDNA_depth/Gal$nCount_ATAC
FeaturePlot(object = Gal, features = "mtDNA_depth_norm", 
                  min.cutoff = "q5", max.cutoff = "q95", 
                  split.by = "hash.ID") & 
  scale_color_viridis_c()
# Out:
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
# plot without title

# %%
options(repr.plot.width = 3, repr.plot.height = 3, repr.plot.res = 300)

(p8 <- ggplot(data = Gal@meta.data, aes(x=hash.ID, y = mtDNA_depth/nCount_ATAC)) +
  geom_violin(scale = "width", aes(fill = hash.ID)) + geom_boxplot(width=0.1, outlier.size=0) + 
  scale_fill_manual(values = cols) + ylab("Normalized mtDNA depth") +
  theme_classic() + NoLegend() + scale_y_log10() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1)))
# Out:
# plot without title

# %%
ggsave(plot = p8, "../plot/1_8_Vln_mtDNA_depth.pdf", width = 4, height = 4)

# %%
stat.test <- Gal@meta.data %>% select(hash.ID, mtDNA_depth_norm) %>% 
  mutate(hash.ID = as.character(hash.ID)) %>%
  wilcox_test(mtDNA_depth_norm ~ hash.ID) %>%
  adjust_pvalue(method = "BH") %>%
  add_significance("p.adj")

# %%
stat.test
# Out:
#    .y.              group1      group2      n1   n2   statistic p
# 1  mtDNA_depth_norm CTRL_Gal_1D CTRL_Gal_3D 2331 1388 1566845    1.08e-01
# 2  mtDNA_depth_norm CTRL_Gal_1D CTRL_Glu    2331 2107 2694975    1.98e-08
# 3  mtDNA_depth_norm CTRL_Gal_1D KI36_Gal_1D 2331 1791 2053066    3.65e-01
# 4  mtDNA_depth_norm CTRL_Gal_1D KI36_Gal_3D 2331 2652 2869371    1.23e-05
# 5  mtDNA_depth_norm CTRL_Gal_1D KI36_Glu    2331 3060 4960280   7.59e-134
# 6  mtDNA_depth_norm CTRL_Gal_3D CTRL_Glu    1388 2107 1648246    1.87e-10
# 7  mtDNA_depth_norm CTRL_Gal_3D KI36_Gal_1D 1388 1791 1261147    4.78e-01
# 8  mtDNA_depth_norm CTRL_Gal_3D KI36_Gal_3D 1388 2652 1768668    4.10e-02
# 9  mtDNA_depth_norm CTRL_Gal_3D KI36_Glu    1388 3060 2986103   9.74e-105
# 10 mtDNA_depth_norm CTRL_Glu    KI36_Gal_1D 2107 1791 1678302    2.60e-09
# 11 mtDNA_depth_norm CTRL_Glu    KI36_Gal_3D 2107 2652 2322476    1.34e-23
# 12 mtDNA_depth_norm CTRL_Glu    KI36_Glu    2107 3060 4233613    7.21e-82
# 13 mtDNA_depth_norm KI36_Gal_1D KI36_Gal_3D 1791 2652 2249523    3.00e-03
# 14 mtDNA_depth_norm KI36_Gal_1D KI36_Glu    1791 3060 3792801   9.64e-111
# 15 mtDNA_depth_norm KI36_Gal_3D KI36_Glu    2652 3060 5863176   1.57e-185
#    p.adj         p.adj.signif
# 1   1.246154e-01 ns
# 2   3.300000e-08 ****
# 3   3.910714e-01 ns
# 4   1.845000e-05 ****
# 5  5.692500e-133 ****
# 6   4.007143e-10 ****
# 7   4.780000e-01 ns
# 8   5.125000e-02 ns
# 9  3.652500e-104 ****
# 10  4.875000e-09 ****
# 11  3.350000e-23 ****
# 12  2.163000e-81 ****
# 13  4.090909e-03 **
# 14 4.820000e-110 ****
# 15 2.355000e-184 ****

# %%
feature.stat <- summarizer(Gal@meta.data, numeric_cols = c("nCount_ATAC", "mtDNA_depth","mtDNA_depth_norm"), hash.ID) %>% 
  tidyr::pivot_longer(cols = -hash.ID, names_to = "name", values_to = "value") %>% 
  mutate(
    feature = sub("^(.*)_[^_]+$", "\\1", name),
    stat = sub("^.*_([^_]+)$", "\\1", name) 
  ) %>% 
  select(hash.ID, feature, stat, value) %>% 
  tidyr::pivot_wider(names_from = hash.ID, values_from = value)
feature.stat
# Out:
#    feature          stat   CTRL_Glu     CTRL_Gal_1D  CTRL_Gal_3D  KI36_Glu
# 1  nCount_ATAC      min    1.001000e+03 1.012000e+03 1.010000e+03 1.011000e+03
# 2  nCount_ATAC      q05    2.111900e+03 1.598500e+03 1.364450e+03 4.562600e+03
# 3  nCount_ATAC      median 1.371700e+04 1.325800e+04 1.097850e+04 2.041000e+04
# 4  nCount_ATAC      q95    3.382370e+04 3.643800e+04 3.474635e+04 3.873215e+04
# 5  nCount_ATAC      max    4.996900e+04 4.964900e+04 4.949700e+04 4.994300e+04
# 6  mtDNA_depth      min    1.023000e+01 1.001000e+01 1.009000e+01 1.001000e+01
# 7  mtDNA_depth      q05    1.645800e+01 1.731000e+01 1.534500e+01 1.455950e+01
# 8  mtDNA_depth      median 6.245000e+01 7.045000e+01 6.170500e+01 5.457000e+01
# 9  mtDNA_depth      q95    1.946670e+02 1.975950e+02 2.224030e+02 2.077840e+02
# 10 mtDNA_depth      max    4.008000e+02 5.226400e+02 5.061000e+02 5.416900e+02
# 11 mtDNA_depth_norm min    3.945053e-04 2.953855e-04 3.263505e-04 2.879277e-04
# 12 mtDNA_depth_norm q05    1.154150e-03 1.212885e-03 1.135907e-03 7.239798e-04
# 13 mtDNA_depth_norm median 5.292132e-03 6.097747e-03 6.535700e-03 3.007984e-03
# 14 mtDNA_depth_norm q95    2.410349e-02 3.339725e-02 3.329414e-02 1.639759e-02
# 15 mtDNA_depth_norm max    1.257464e-01 1.245686e-01 2.659485e-01 1.799772e-01
#    KI36_Gal_1D  KI36_Gal_3D
# 1  1.003000e+03 1.009000e+03
# 2  2.961000e+03 2.778500e+03
# 3  1.750500e+04 1.878800e+04
# 4  3.991700e+04 4.046930e+04
# 5  4.962000e+04 4.991300e+04
# 6  1.009000e+01 1.034000e+01
# 7  1.775500e+01 2.321100e+01
# 8  1.057100e+02 1.253000e+02
# 9  3.407150e+02 3.407595e+02
# 10 9.561800e+02 7.396200e+02
# 11 2.462704e-04 3.459666e-04
# 12 1.025978e-03 1.321095e-03
# 13 6.762603e-03 7.005851e-03
# 14 3.415617e-02 3.996231e-02
# 15 4.229204e-01 1.957065e-01

# %%
pull_coverage <- function(SE, cells, resolution = 5){
  zoo::rollmean(rowMeans(assays(SE)[['coverage']]), resolution)
}

CTRL_Glu_3D_CB <- WhichCells(Gal, idents = "CTRL_Glu"    )
CTRL_Gal_1D_CB <- WhichCells(Gal, idents = "CTRL_Gal_1D" )
CTRL_Gal_3D_CB <- WhichCells(Gal, idents = "CTRL_Gal_3D" )
KI36_Glu_3D_CB <- WhichCells(Gal, idents = "KI36_Glu"    )
KI36_Gal_1D_CB <- WhichCells(Gal, idents = "KI36_Gal_1D" )
KI36_Gal_3D_CB <- WhichCells(Gal, idents = "KI36_Gal_3D" )

cov_df <- data.frame(
  pos = zoo::rollmean(1:16569, 5),
  CTRL_Glu    = pull_coverage(mitoSE[,CTRL_Glu_3D_CB]),
  CTRL_Gal_1D = pull_coverage(mitoSE[,CTRL_Gal_1D_CB]),
  CTRL_Gal_3D = pull_coverage(mitoSE[,CTRL_Gal_3D_CB]),
  KI36_Glu    = pull_coverage(mitoSE[,KI36_Glu_3D_CB]),
  KI36_Gal_1D = pull_coverage(mitoSE[,KI36_Gal_1D_CB]),
  KI36_Gal_3D = pull_coverage(mitoSE[,KI36_Gal_3D_CB]))

# %%
source("../../global/mtGene_color.R")

p9 <- cov_df %>% reshape2::melt(id.vars = "pos") %>% # dplyr::filter(value > 5) %>%
  ggplot() +
  geom_line(aes(x = pos, y = value, color = variable)) +
  #scale_y_continuous(limits = c(-3, 75), expand = c(0,0)) +
  scale_x_continuous(breaks = seq(0,16596, by = 3000), expand = c(0,0)) + 
  scale_color_manual(values = cols) +
  labs(x = "Position on mtDNA chromosome", y = "Roll mean coverage") + 
  geom_rect(data = mitochondrial_data, aes(xmin = Starting, xmax = Ending, ymin = -10, ymax = 0, fill = color), alpha = 1) +
  scale_fill_manual(values = mtGene_colors) +
  # coord_polar() + 
  guides(fill=guide_legend(ncol=2))+
  theme_classic() + NoLegend() + facet_wrap(~variable, ncol = 3)

# %%
options(repr.plot.width = 6, repr.plot.height = 4, repr.plot.res = 300)
p9
# Out:
# plot without title

# %%
ggsave(plot = p9, "../plot/1_9_roll_mean_cov.pdf", width = 7, height = 4)

# %% [markdown]
# ### Variant calling

# %%
CTRL_GluD3_CB <- WhichCells(Gal, idents = "CTRL_Glu"    )
CTRL_GalD1_CB <- WhichCells(Gal, idents = "CTRL_Gal_1D" )
CTRL_GalD3_CB <- WhichCells(Gal, idents = "CTRL_Gal_3D" )
KI36_GluD3_CB <- WhichCells(Gal, idents = "KI36_Glu"    )
KI36_GalD1_CB <- WhichCells(Gal, idents = "KI36_Gal_1D" )
KI36_GalD3_CB <- WhichCells(Gal, idents = "KI36_Gal_3D" )

# %%
CTRL_CB = c(CTRL_GluD3_CB, CTRL_GalD1_CB, CTRL_GalD3_CB)
KI36_CB = c(KI36_GluD3_CB, KI36_GalD1_CB, KI36_GalD3_CB)

suppressWarnings(mmat_CTRL <- call_mutations_mgatk(mitoSE[,CTRL_CB]))
suppressWarnings(mmat_KI36 <- call_mutations_mgatk(mitoSE[,KI36_CB]))
# Out:
# [1] "A"
# [1] "C"
# [1] "G"
# [1] "T"
# [1] "A"
# [1] "C"
# [1] "G"
# [1] "T"

# %%
options(repr.plot.width = 4, repr.plot.height = 4, repr.plot.res = 300)
VarPlot(mmat_CTRL, "CTRL Galactose Treament")
VarPlot(mmat_KI36, "KI36 Galactose Treament")
# Out:
# Warning message in trans$transform(limits):
# “NaNs produced”
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
#
# Warning message in trans$transform(limits):
# “NaNs produced”
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
#
# Warning message:
# “Removed 8 rows containing missing values (geom_point).”
# Warning message:
# “Removed 8 rows containing missing values (geom_point).”
# plot without title
# plot without title

# %%
saveRDS(Gal, "../output/1_preprocessed_HEK_POLG_galactose_seurat.rds")

# %%
saveRDS(mmat_CTRL, "../output/1_mmat_CTRL_Gal.rds")
saveRDS(mmat_KI36, "../output/1_mmat_KI36_Gal.rds")
